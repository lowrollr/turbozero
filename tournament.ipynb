# %%
import torch
import matplotlib.pyplot as plt
from turbozero import *

# %%
tournament = load_tournament_nb(
    config_file='./example_configs/tournament.yaml', #TODO: specify a config file
    gpu=torch.cuda.is_available(),
    debug=False,
    logfile='turbozero.log',
    verbose_logging=True
)

# %%
tournament.run(interactive=True)
# Out:
# {'greedy_moves': 1528,
#  'greedy_tiles': 1506,
#  'corners': 1507,
#  'corners_and_edges': 1515,
#  'random': 1440}
