# %%
from train import load_from_checkpoint
from resnet2 import ResNet2Heads

# %%
MODEL_TO_LOAD = 'resnet64v2_ep6250.pt'

_, _, _, _, metrics_history, _, _ = load_from_checkpoint(MODEL_TO_LOAD, ResNet2Heads, load_replay_memory=True)
# Out:
# /Users/marshingjay/miniconda3/envs/python3/lib/python3.8/site-packages/torch/serialization.py:1049: UserWarning: This figure was saved with matplotlib version 3.5.3 and is unlikely to function correctly.
#   result = unpickler.load()

# %%
metrics_history.plot_history(offset=5000, window_size=100)

# %%
m, s = metrics_history.get_move_mean_and_stddev()
m - 2*s
# Out:
# 208.4790247538134

# %%
import matplotlib.pyplot as plt
import numpy as np

tau_shift = m - 2*s
tau_divisor = s
xs = np.linspace(0, 1500, 1500)

plt.plot(xs, [0.5 * np.tanh((x - tau_shift) / 80) + 0.5 for x in xs])
